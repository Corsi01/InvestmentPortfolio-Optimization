# %% [markdown]
# # Reconstruction of the NASDAQ index composition in the years covered by the analysis

# %% [markdown]
# In order to conduct an analysis as accurate as possible, we needed to retrieve not only the time series of prices for the stocks that currently make up the NASDAQ index, but also the change in the index's composition over the past years.

# %%
import pandas as pd
import numpy as np
import os
import re
from datetime import datetime

# %% [markdown]
# Through the document *nasdaq_constituent.json*, we have reconstructed all stocks that joined or ceased to be part of the Index during the period we considered:

# %%
changes = pd.read_json('nasdaq_constituent.json')
changes.date.astype
# Out:
# <bound method NDFrame.astype of 0     2024-03-18
# 1     2023-12-18
# 2     2023-12-18
# 3     2023-12-18
# 4     2023-12-18
#          ...
# 401   1995-03-06
# 402   1995-02-27
# 403   1995-02-13
# 404   1995-01-27
# 405   1995-01-27
# Name: date, Length: 406, dtype: datetime64[ns]>

# %% [markdown]
# The last update of the NASDAQ in the year 2013 was on 23 December, so we exclude previous updates:

# %%
changes = changes[changes.date >= '2013-12-01']
changes.shape
# Out:
# (121, 7)

# %%
dates = changes["date"].unique().tolist()
len(dates)
# Out:
# 55

# %%
url = 'https://en.wikipedia.org/wiki/Nasdaq-100'
# Read all tables from the webpage
tables = pd.read_html(url)
tickers = tables[4]["Ticker"].to_list()
len(tickers)
# Out:
# 101

# %% [markdown]
# We can observe that the number of stocks exceeds by one; this is because the google share appears in two versions (with and without dividends).

# %% [markdown]
# We reconstructed the history of the index composition during the period considered and saved the data in a dataframe:

# %%
# Creating the DataFrame with the column named "components"
composition = pd.DataFrame()

# %%
for date in dates:

    change = changes[changes.date == date]
    added = change["symbol"].tolist()
    removed = change["removedTicker"].tolist()

    # Unique elements in 'a'
    unique_added = [a for a in added if a not in removed]

    # Unique elements in 'b'
    unique_removed = [r for r in removed if r not in added]

    print("\n", date)
    print(len(tickers))


    new_tickers = []

    for r in unique_removed:

        if (r != '') & (r not in tickers):

            print("add: ", r)
            tickers.append(r)

    new_tickers = tickers.copy()


    print(len(new_tickers))

    new_tickers_2 = []

    for a in unique_added:

        if (a != '') & (a in new_tickers):

            print("remove ",a)
            new_tickers.remove(a)

    new_tickers_2 = new_tickers.copy()

    print(len(new_tickers_2))

    if (len(added) != len(removed)):
        count += 1

    temp_df = pd.DataFrame({"components": [new_tickers_2]})
    temp_df.index = [date]

    tickers = new_tickers_2.copy()

    composition = pd.concat([composition, temp_df], axis = 0)
# Out:
#  2024-03-18 00:00:00
# 96
# add:  SPLK
# 97
# 97
#
#  2023-12-18 00:00:00
# 97
# add:  SGEN
# add:  ALGN
# add:  ENPH
# add:  JD
# add:  LCID
# add:  ZM
# 103
# remove  SPLK
# 102
#
#  2023-07-17 00:00:00
# 102
# 102
# 102
#
#  2023-06-20 00:00:00
# 102
# add:  RIVN
# 103
# 103
#
#  2023-06-07 00:00:00
# 103
# 103
# 103
#
#  2022-12-19 00:00:00
# 103
# add:  VRSN
# add:  SWKS
# add:  SPLK
# add:  MTCH
# add:  DOCU
# 108
# remove  RIVN
# 107
#
#  2022-11-21 00:00:00
# 107
# add:  OKTA
# 108
# remove  ENPH
# 107
#
#  2022-02-22 00:00:00
# 107
# 107
# 107
#
#  2022-02-02 00:00:00
# 107
# 107
# 107
#
#  2022-01-24 00:00:00
# 107
# add:  PTON
# 108
# 108
#
#  2021-12-20 00:00:00
# 108
# add:  CDW
# add:  TCOM
# add:  INCY
# add:  FOX
# 112
# remove  LCID
# 111
#
#  2021-08-26 00:00:00
# 111
# 111
# 111
#
#  2021-07-21 00:00:00
# 111
# 111
# 111
#
#  2020-12-21 00:00:00
# 111
# add:  BMRN
# add:  TTWO
# add:  ULTA
# 114
# remove  MTCH
# remove  OKTA
# remove  PTON
# 111
#
#  2020-10-19 00:00:00
# 111
# 111
# 111
#
#  2020-08-24 00:00:00
# 111
# 111
# 111
#
#  2020-07-20 00:00:00
# 111
# add:  CSGP
# 112
# 112
#
#  2020-06-22 00:00:00
# 112
# add:  UAL
# 113
# remove  DOCU
# 112
#
#  2020-04-30 00:00:00
# 112
# add:  WLTW
# 113
# remove  ZM
# 112
#
#  2020-04-20 00:00:00
# 112
# add:  AAL
# 113
# 113
#
#  2019-12-23 00:00:00
# 113
# add:  HAS
# add:  JBHT
# 115
# remove  SPLK
# remove  CSGP
# remove  CDW
# remove  SGEN
# 111
#
#  2019-11-21 00:00:00
# 111
# 111
# 111
#
#  2018-12-24 00:00:00
# 111
# add:  HOLX
# add:  SHPG
# 113
# remove  NTAP
# remove  UAL
# remove  VRSN
# remove  WLTW
# 109
#
#  2018-11-19 00:00:00
# 109
# 109
# 109
#
#  2018-11-05 00:00:00
# 109
# 109
# 109
#
#  2018-07-23 00:00:00
# 109
# add:  DISH
# 110
# 110
#
#  2018-03-08 00:00:00
# 110
# 110
# 110
#
#  2017-12-08 00:00:00
# 110
# add:  TSCO
# add:  NCLH
# 112
# remove  TTWO
# 111
#
#  2017-10-23 00:00:00
# 111
# 111
# remove  ALGN
# 110
#
#  2017-06-19 00:00:00
# 110
# 110
# 110
#
#  2017-04-24 00:00:00
# 110
# add:  TRIP
# 111
# remove  WYNN
# 110
#
#  2017-03-20 00:00:00
# 110
# 110
# 110
#
#  2017-02-07 00:00:00
# 110
# add:  NXPI
# 111
# remove  JBHT
# 110
#
#  2016-12-09 00:00:00
# 110
# add:  NTAP
# 111
# remove  HAS
# remove  HOLX
# remove  KLAC
# 108
#
#  2016-10-19 00:00:00
# 108
# 108
# remove  SHPG
# 107
#
#  2016-07-18 00:00:00
# 107
# add:  ENDP
# 108
# remove  MCHP
# 107
#
#  2016-06-20 00:00:00
# 107
# add:  BATRA
# 108
# remove  XRAY
# 107
#
#  2016-04-18 00:00:00
# 107
# 107
# remove  BATRA
# 106
#
#  2016-03-16 00:00:00
# 106
# 106
# 106
#
#  2016-02-22 00:00:00
# 106
# add:  KLAC
# 107
# 107
#
#  2015-12-21 00:00:00
# 107
# add:  WYNN
# 108
# remove  TCOM
# remove  ENDP
# remove  EXPE
# remove  MXIM
# remove  NCLH
# remove  ULTA
# 102
#
#  2015-12-15 00:00:00
# 102
# 102
# 102
#
#  2015-11-11 00:00:00
# 102
# 102
# 102
#
#  2015-10-07 00:00:00
# 102
# 102
# remove  INCY
# 101
#
#  2015-08-03 00:00:00
# 101
# 101
# remove  SWKS
# 100
#
#  2015-07-31 00:00:00
# 100
# 100
# 100
#
#  2015-07-29 00:00:00
# 100
# 100
# remove  JD
# 99
#
#  2015-07-27 00:00:00
# 99
# 99
# remove  BMRN
# 98
#
#  2015-07-24 00:00:00
# 98
# 98
# 98
#
#  2015-07-01 00:00:00
# 98
# 98
# 98
#
#  2015-03-23 00:00:00
# 98
# 98
# 98
#
#  2014-12-22 00:00:00
# 98
# add:  EXPE
# add:  MXIM
# 100
# remove  FOX
# remove  AAL
# 98
#
#  2014-11-06 00:00:00
# 98
# 98
# 98
#
#  2014-04-03 00:00:00
# 98
# 98
# 98
#
#  2013-12-23 00:00:00
# 98
# add:  MCHP
# add:  XRAY
# 100
# remove  DISH
# remove  NXPI
# remove  TRIP
# remove  TSCO
# 96

# %%
composition.iloc[::-1]
# Out:
#                                                    components
# 2013-12-23  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2014-04-03  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2014-11-06  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2014-12-22  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2015-03-23  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2015-07-01  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2015-07-24  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2015-07-27  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2015-07-29  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2015-07-31  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2015-08-03  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2015-10-07  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2015-11-11  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2015-12-15  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2015-12-21  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2016-02-22  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2016-03-16  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2016-04-18  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2016-06-20  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2016-07-18  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2016-10-19  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2016-12-09  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2017-02-07  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2017-03-20  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2017-04-24  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2017-06-19  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2017-10-23  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2017-12-08  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2018-03-08  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2018-07-23  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2018-11-05  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2018-11-19  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2018-12-24  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2019-11-21  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2019-12-23  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2020-04-20  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2020-04-30  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2020-06-22  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2020-07-20  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2020-08-24  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2020-10-19  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2020-12-21  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2021-07-21  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2021-08-26  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2021-12-20  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2022-01-24  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2022-02-02  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2022-02-22  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2022-11-21  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2022-12-19  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2023-06-07  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2023-06-20  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2023-07-17  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2023-12-18  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...
# 2024-03-18  [ADBE, GOOGL, AMZN, AMGN, ADI, AAPL, AMAT, ARM...

# %%
composition.to_csv('Data/nas_comps.csv')
